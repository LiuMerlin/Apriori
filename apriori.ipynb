# %%
from efficient_apriori import apriori
# 设置数据集
data = [('牛奶','面包','尿布'),
           ('可乐','面包', '尿布', '啤酒'),
           ('牛奶','尿布', '啤酒', '鸡蛋'),
           ('面包', '牛奶', '尿布', '啤酒'),
           ('面包', '牛奶', '尿布', '可乐')]
# 挖掘频繁项集和频繁规则
itemsets, rules = apriori(data, min_support=0.5,  min_confidence=1)
print(itemsets)
print(rules)
# Out:
# {1: {('啤酒',): 3, ('尿布',): 5, ('牛奶',): 4, ('面包',): 4}, 2: {('啤酒', '尿布'): 3, ('尿布', '牛奶'): 4, ('尿布', '面包'): 4, ('牛奶', '面包'): 3}, 3: {('尿布', '牛奶', '面包'): 3}}
# [{啤酒} -> {尿布}, {牛奶} -> {尿布}, {面包} -> {尿布}, {牛奶, 面包} -> {尿布}]

# %%
# -*- coding: utf-8 -*-
# 下载某个导演的电影数据集
from efficient_apriori import apriori
from lxml import etree
import time
import csv
from selenium import webdriver
from selenium.webdriver.firefox.options import Options

firefox_options = Options()
fire_driver = webdriver.Firefox(options=firefox_options)
driver = webdriver.Firefox(executable_path = r'C:\Users\JM&SM\Desktop\geckodriver.exe')

# 设置想要下载的导演 数据集
director = u'冯小刚'
# 写CSV文件
file_name = './' + director + '.csv'
base_url = 'https://movie.douban.com/subject_search?search_text='+director+'&cat=1002&start='
out = open(file_name,'w', newline='', encoding='utf-8-sig')
csv_write = csv.writer(out, dialect='excel')
flags=[]
# 下载指定页面的数据
def download(request_url):
  driver.get(request_url)
  time.sleep(1)
  html = driver.find_element_by_xpath("//*").get_attribute("outerHTML")
  html = etree.HTML(html)
  # 设置电影名称，导演演员 的XPATH
  movie_lists = html.xpath("/html/body/div[@id='wrapper']/div[@id='root']/div[1]//div[@class='item-root']/div[@class='detail']/div[@class='title']/a[@class='title-text']")
  name_lists = html.xpath("/html/body/div[@id='wrapper']/div[@id='root']/div[1]//div[@class='item-root']/div[@class='detail']/div[@class='meta abstract_2']")
  # 获取返回的数据个数
  num = len(movie_lists)
  if num > 15: #第一页会有16条数据
    # 默认第一个不是，所以需要去掉
    movie_lists = movie_lists[1:]
    name_lists = name_lists[1:]
  for (movie, name_list) in zip(movie_lists, name_lists):
    # 会存在数据为空的情况
    if name_list.text is None: 
      continue
    # 显示下演员名称
    print(name_list.text)
    names = name_list.text.split('/')
    # 判断导演是否为指定的director
    if names[0].strip() == director and movie.text not in flags:
      # 将第一个字段设置为电影名称
      names[0] = movie.text
      flags.append(movie.text)
      csv_write.writerow(names)
  print('OK') # 代表这页数据下载成功
  print(num)
  if num >= 14: #有可能一页会有14个电影
    # 继续下一页
    return True
  else:
    # 没有下一页
    return False

# 开始的ID为0，每页增加15
start = 0
while start<10000: #最多抽取1万部电影
  request_url = base_url + str(start)
  # 下载数据，并返回是否有下一页
  flag = download(request_url)
  if flag:
    start = start + 15
  else:
    break
out.close()
print('finished')
# Out:
# 徐熙娣 / 蔡康永 / 黄圣依 / 杨子 / 钟欣潼 / 赖弘国 / 金瀚 / 薇娅
# 李宇春 / 成龙 / 吴京 / 谢楠 / 黄晓明 / 林心如 / 关晓彤 / 景甜
# 冯小刚 / 陈可辛 / 张译 / 万茜 / 徐克 / 张涵予 / 程耳 / 林咏琛
# 陈坤 / 赵薇 / 冯小刚 / 苏有朋 / 王嘉 / 许晴 / 陶晶莹 / 舒淇
# 詹姆斯·卡梅隆 / 基努·里维斯 / 张纪中 / 尔冬升 / 姚晨 / 邬君梅 / 周冬雨 / 冯小刚
# 贾樟柯 / 刘震云 / 张扬 / 陈凯歌 / 唐大年 / 吴楠 / 颜丙燕 / 冯小刚
# 冯小刚 / 白百何 / 文章 / 张子枫 / 宁静 / 王为一 / 严寄洲 / 思芜
# 王小帅 / 李少红 / 徐静蕾 / 薛晓路 / 贾樟柯 / 陆川 / 宁浩 / 万玛才旦
# 张震 / 周迅 / 张艾嘉 / 冯小刚 / 刘昊然 / 游晓颖 / 钟楚曦 / 苗苗
# José María Sánchez-Chiquito Moró / Patxi Barko / 范冰冰 / 冯小刚
# 叶京 / 刘芮麟 / 柳明明 / 王学敏 / 李倩 / 戴子翔 / 耿一智 / 李九霄
# 费振翔 / 石凉 / 邵桐 / 赵小锐 / 张博宇
# 李诚儒 / 方青卓 / 白凯南 / 栗坤 / 林志玲 / 李谷一 / 陈德容 / 汪明荃
# 张涵予
# OK
# 15
# 侯咏 / 聂远 / 秦海璐 / 景岗山 / 周晓鸥 / 石兆琪 / 尹媗 / 国永振
# 蔡小团 / 张国立 / 张默 / 徐帆 / 张涵予 / 刘震云 / 史航
# 三島奈津子
# 刘国权 / 梁天 / 葛优 / 原利 / 陈裕德 / 丁一
# OK
# 6
# finished

# %%
# -*- coding: utf-8 -*-
from efficient_apriori import apriori
import csv
director = u'冯小刚'
file_name = './'+director+'.csv'
lists = csv.reader(open(file_name, 'r', encoding='utf-8-sig'))
# 数据加载
data = []
for names in lists:
     name_new = []
     for name in names:
           # 去掉演员数据中的空格
           name_new.append(name.strip())
     data.append(name_new[1:])
# 挖掘频繁项集和关联规则
itemsets, rules = apriori(data, min_support=0.1,  min_confidence=1)
print(itemsets)
print(rules)
# Out:
# {1: {('修宗迪',): 3, ('傅彪',): 3, ('刘蓓',): 3, ('张国立',): 5, ('张涵予',): 5, ('徐帆',): 14, ('李诚儒',): 3, ('范伟',): 5, ('范冰冰',): 4, ('葛优',): 12, ('陈道明',): 3}, 2: {('修宗迪', '徐帆'): 3, ('刘蓓', '徐帆'): 3, ('张国立', '徐帆'): 4, ('张国立', '葛优'): 3, ('张涵予', '葛优'): 3, ('徐帆', '葛优'): 6, ('徐帆', '陈道明'): 3, ('范伟', '葛优'): 4}}
# [{修宗迪} -> {徐帆}, {刘蓓} -> {徐帆}, {陈道明} -> {徐帆}]
